# %% [markdown]
# <a href="https://colab.research.google.com/github/Tagore-7/python_projects/blob/main/slot_machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

MAX_LINES = 3
MAX_BET = 100
MIN_BET = 1

ROWS = 3
COLS = 3

symbol_count = {
    "A":2,
    "B":4,
    "C":6,
    "D":8
}

symbol_value = {
     "A":5,
    "B":4,
    "C":3,
    "D":2
}


def check_winnings(columns, lines, bet, values):
  winnings = 0
  winning_lines = []
  for line in range(lines):
    symbol = columns[0][line]
    for column in columns:
      symbol_to_check = column[line]
      if symbol_to_check != symbol:
        break
    else:
      winnings += values[symbol] * bet
      winning_lines.append(line + 1)
  return winnings, winning_lines

def get_slot_machine_spin(rows, cols, symbols):
  all_symbols = []
  for symbol, symbol_count in symbols.items():
    for _ in range(symbol_count):
      all_symbols.append(symbol)

  columns = []
  for _ in range(cols):
    column = []
    current_symbols = all_symbols[:]
    for _ in range(rows):
      value = random.choice(current_symbols)
      current_symbols.remove(value)
      column.append(value)

    columns.append(column)
  return columns


def print_slot_machine(columns):
  for row in range(len(columns[0])):
    for i, column in enumerate(columns):
      if i != len(column) - 1:
        print(column[row], end = " | ")
      else:
        print(column[row], end = "")
    print()


def deposit():
  while True:
    amount = input("How much would you like to deposit? $")
    if amount.isdigit():
      if int(amount) > 0:
        amount = int(amount)
        break
      else:
        print("please enter amount greater than 0")
    else:
      print(f"please enter valid amount in numbers")
  return amount

def get_number_of_lines():
  while True:
    lines = input(f"Enter the number of lines to bet on 1 - {MAX_LINES}: ")
    if lines.isdigit():
      lines = int(lines)
      if 1 <= lines <= MAX_LINES:
        break
      else:
        print(f"enter a valid number of lines")
    else:
      print("enter a valid number")
  return lines

def get_bet():
  while True:
    amount = input("How much would you like to bet? on each line $")
    if amount.isdigit():
      if MIN_BET <= int(amount) <= MAX_BET:
        amount = int(amount)
        break
      else:
        print(f"please enter bet between ${MIN_BET} - ${MAX_BET} ")
    else:
      print(f"please enter valid bet in numbers")
  return amount

def spin(balance):
  lines = get_number_of_lines()
  while True:
    bet = get_bet()
    total_bet = bet * lines
    if total_bet > balance:
      print(f"You don't have enough balance to bet ${total_bet}, you current balance is {balance}")
    else:
      break
  print(f"you are betting ${bet} on {lines} lines. Total bet is equal to ${total_bet}")

  solts = get_slot_machine_spin(ROWS, COLS, symbol_count)
  print_slot_machine(solts)
  winnings, winning_lines = check_winnings(solts, lines, bet, symbol_value)
  print(f"you Won: ${winnings}")
  print("you won on following lines", *winning_lines)
  return winnings - total_bet



def main():
  balance = deposit()
  while True:
    print(f" current balance is ${balance}")
    answer = input("press enter to spin (q to quit)")
    if answer == "q":
      break
    balance +=spin(balance)

  print(f" you left with ${balance}")
main()
# Out:
# How much would you like to deposit? $1000
#  current balance is $1000
# press enter to spin (q to quit)
# Enter the number of lines to bet on 1 - 3: 3
# How much would you like to bet? on each line $100
# you are betting $100 on 3 lines. Total bet is equal to $300
# C | D | D
# B | D | C
# A | B | B
# you Won: $0
# you won on following lines
#  current balance is $700
# press enter to spin (q to quit)
# Enter the number of lines to bet on 1 - 3: 3
# How much would you like to bet? on each line $200
# please enter bet between $1 - $100
# How much would you like to bet? on each line $100
# you are betting $100 on 3 lines. Total bet is equal to $300
# C | A | D
# D | B | C
# B | D | B
# you Won: $0
# you won on following lines
#  current balance is $400
# press enter to spin (q to quit)
# Enter the number of lines to bet on 1 - 3: 3
# How much would you like to bet? on each line $100
# you are betting $100 on 3 lines. Total bet is equal to $300
# C | D | D
# A | C | A
# B | B | B
# ...
